# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# graph_vectors function
# %run "./aux_functions/graph_vectors.ipynb"

# %%
# Vectors
v1 = np.array([2, 5])
v2 = np.array([3, 2])

# %%
# Linear combination of v1 and v2
v1v2 = 2 * v1 + 1 * v2

# %%
print(v1v2)
# Out:
# [ 7 12]

# %%
# Graph a vector linear combination
graph_vectors([v1, v2, v1v2], ['yellow', 'red', 'orange'])
plt.xlim(-1, 8)
plt.ylim(-1, 12)
plt.show()

# %%
# Graph vector lineal combinations a * v1 + b * v2 (for -15 <= a, b < 15 and a, b integers)
for a in range(-15, 15):
    for b in range(-15, 15):
        plt.scatter(v1[0] * a + v2[0] * b, v1[1] * a + v2[1] * b,
                   marker='.', color='blue')
        
plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')

plt.show()
